# %% [markdown]
# <a href="https://colab.research.google.com/github/ganeshsembedded-maker/ml-end-to-end-project/blob/main/ProjectOfMiTHpynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
datasetTrain = pd.read_csv('/content/Train-1617360447408-1660719685476 (1).csv')
display(datasetTrain.head(10))
# Out:
#    index  encounter_id  patient_id             race  gender      age weight  \
# 0  69375     197029140    51521940         Hispanic    Male  [80-90)      ?
# 1  57272     163571946    92631357        Caucasian    Male  [60-70)      ?
# 2  82347     256497366    30023982        Caucasian  Female  [50-60)      ?
# 3  89608     289891212    93606021  AfricanAmerican  Female  [70-80)      ?
# 4  24091      81873900    23464296        Caucasian    Male  [70-80)      ?
# 5  11756      48391902    29635362  AfricanAmerican    Male  [40-50)      ?
# 6  42376     130669056    35476317        Caucasian    Male  [70-80)      ?
# 7  91744     313193054   171347630        Caucasian  Female  [40-50)      ?
# 8  27014      88645302    20811105        Caucasian  Female  [70-80)      ?
# 9  95964     369018230   115650671        Caucasian    Male  [70-80)      ?
#
#    time_in_hospital       medical_specialty  num_lab_procedures  ...  X19  \
# ...

# %% [markdown]
# load the Train Dataset

# %%
datasetTest = pd.read_csv('/content/test-1617360461595-1660719701431.csv')
display(datasetTest.head(10))
# Out:
#    index  encounter_id  patient_id             race  gender       age weight  \
# 0  11128      46325466     3928383        Caucasian  Female   [70-80)      ?
# 1  79758     245219616    60926103        Caucasian    Male   [60-70)      ?
# 2  52497     155321232    25234848  AfricanAmerican    Male   [70-80)      ?
# 3  64504     179491944    86935374        Caucasian  Female   [70-80)      ?
# 4    987       7425954     2486826  AfricanAmerican  Female   [50-60)      ?
# 5   8786      39200892    55117323        Caucasian    Male   [60-70)      ?
# 6  93189     332494934   141388079        Caucasian    Male   [70-80)      ?
# 7  69599     198113130    64868238        Caucasian    Male  [90-100)      ?
# 8  15536      59546136      570582  AfricanAmerican    Male   [30-40)      ?
# 9  82050     255199080    90050157        Caucasian  Female   [50-60)      ?
#
#    time_in_hospital       medical_specialty  num_lab_procedures  ...  X18  \
# ...

# %% [markdown]
# Load The Test DataSet

# %%
copyData = datasetTrain.copy()
copyData1 = datasetTest.copy()

# %%
plt.figure(figsize=(5, 6))
sns.barplot(x='readmitted', y='time_in_hospital', data=copyData)
plt.title('Average Time in Hospital by Readmission Status')
plt.xlabel('Readmitted')
plt.ylabel('Average Time in Hospital (days)')
plt.show()

# %%
plt.figure(figsize=(6, 8))
sns.barplot(x='readmitted', y='num_medications', data=copyData)
plt.title('number Of medications')
plt.xlabel('Readmitted')
plt.ylabel('num_medications')
plt.show()

# %%
plt.figure(figsize=(6, 8))
sns.barplot(x='readmitted', y='num_lab_procedures', data=copyData)
plt.title('diabetesMed graph')
plt.xlabel('Readmitted')
plt.ylabel('diabetesMed')
plt.show()

# %%
plt.figure(figsize=(6, 8))
sns.barplot(x='readmitted', y='age', data=copyData)
plt.title('diabetesMed graph')
plt.xlabel('Readmitted')
plt.ylabel('diabetesMed')
plt.show()

# %%
copyData.drop(['X1','X2'], axis=1)
copyData.drop(['weight'], axis=1)
# Out:
#        index  encounter_id  patient_id             race  gender      age  \
# 0      69375     197029140    51521940         Hispanic    Male  [80-90)
# 1      57272     163571946    92631357        Caucasian    Male  [60-70)
# 2      82347     256497366    30023982        Caucasian  Female  [50-60)
# 3      89608     289891212    93606021  AfricanAmerican  Female  [70-80)
# 4      24091      81873900    23464296        Caucasian    Male  [70-80)
# ...      ...           ...         ...              ...     ...      ...
# 66582  39934     124202466    23450508        Caucasian  Female  [70-80)
# 66583  47366     145667070    29324601        Caucasian    Male  [80-90)
# 66584  76555     231061116     2179062        Caucasian  Female  [60-70)
# 66585  25392      84911682    20531754                ?  Female  [80-90)
# 66586  51312     153167502    81985473        Caucasian  Female  [80-90)
#
#        time_in_hospital medical_specialty  num_lab_procedures  num_procedures  \
# ...

# %%
copyData.isnull().sum()
# Out:
# index                     0
# encounter_id              0
# patient_id                0
# race                      0
# gender                    0
# age                       0
# weight                    0
# time_in_hospital          0
# medical_specialty         0
# num_lab_procedures        0
# num_procedures            0
# num_medications           0
# number_outpatient         0
# number_emergency          0
# number_inpatient          0
# diag_1                    0
# diag_2                    0
# diag_3                    0
# diag_4                    0
# diag_5                    0
# number_diagnoses          0
# X1                    63104
# X2                    55451
# X3                        0
# X4                        0
# X5                        0
# X6                        0
# X7                        0
# X8                        0
# X9                        0
# X10                       0
# X11                       0
# X12                       0
# ...

# %%
X = copyData.drop(['readmitted'],axis=1)
Y =  copyData['readmitted']

# %%
copyData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66587 entries, 0 to 66586
# Data columns (total 49 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   index               66587 non-null  int64
#  1   encounter_id        66587 non-null  int64
#  2   patient_id          66587 non-null  int64
#  3   race                66587 non-null  object
#  4   gender              66587 non-null  object
#  5   age                 66587 non-null  object
#  6   weight              66587 non-null  object
#  7   time_in_hospital    66587 non-null  int64
#  8   medical_specialty   66587 non-null  object
#  9   num_lab_procedures  66587 non-null  int64
#  10  num_procedures      66587 non-null  int64
#  11  num_medications     66587 non-null  int64
#  12  number_outpatient   66587 non-null  int64
#  13  number_emergency    66587 non-null  int64
#  14  number_inpatient    66587 non-null  int64
# ...

# %%
obj_cols = copyData.select_dtypes(include='object').columns
print(len(obj_cols))
print(obj_cols)
# Out:
# 36
# Index(['race', 'gender', 'age', 'weight', 'medical_specialty', 'diag_1',
#        'diag_2', 'diag_3', 'diag_4', 'X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7',
#        'X8', 'X9', 'X10', 'X11', 'X12', 'X13', 'X14', 'X15', 'X16', 'X17',
#        'X18', 'X19', 'X20', 'X21', 'X22', 'X23', 'X24', 'X25', 'change',
#        'diabetesMed'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
import pandas as pd

for col in obj_cols:
    le = LabelEncoder()

    combined = pd.concat([
        copyData[col].astype(str),
        copyData1[col].astype(str)
    ], axis=0)

    le.fit(combined)

    copyData[col] = le.transform(copyData[col].astype(str))
    copyData1[col] = le.transform(copyData1[col].astype(str))

# %%
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(
    X, Y,
    test_size=0.2,
    random_state=42,
    stratify=Y
)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score

X = copyData.drop(['readmitted'], axis=1)
Y = copyData['readmitted']

from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(
    X,
    Y,
    test_size=0.2,
    random_state=42,
    stratify=Y
)

lr = LogisticRegression(max_iter=1000)
lr.fit(X_train, y_train)

y_pred_lr = lr.predict(X_val)

print("Logistic Regression F1 Score:", f1_score(y_val, y_pred_lr))
# Out:
# Logistic Regression F1 Score: 0.4274794003772461

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score

rf = RandomForestClassifier(
    n_estimators=300,
    random_state=42,
    class_weight='balanced'
)

rf.fit(X_train, y_train)

y_pred_rf = rf.predict(X_val)

rf_f1 = f1_score(y_val, y_pred_rf)
print("Random Forest F1 Score:", rf_f1)
# Out:
# Random Forest F1 Score: 0.7650449228682827

# %%
from xgboost import XGBClassifier
from sklearn.metrics import f1_score

xgb = XGBClassifier(
    n_estimators=400,
    max_depth=6,
    learning_rate=0.1,
    subsample=0.8,
    colsample_bytree=0.8,
    scale_pos_weight=2,
    eval_metric='logloss'
)

xgb.fit(X_train, y_train)

y_pred_xgb = xgb.predict(X_val)

xgb_f1 = f1_score(y_val, y_pred_xgb)
print("XGBoost F1 Score:", xgb_f1)
# Out:
# XGBoost F1 Score: 0.7187670485542826

# %%
print("Logistic Regression F1 Score:",f1_score(y_val, y_pred_lr)*100)
print("Random Forest:", rf_f1*100)
print("XGBoost:", xgb_f1*100)
# Out:
# Logistic Regression F1 Score: 42.74794003772461
# Random Forest: 76.50449228682828
# XGBoost: 71.87670485542826

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

cm = confusion_matrix(y_val, y_pred_xgb)

sns.heatmap(cm, annot=True, fmt='d', cmap='Reds')
plt.title("Confusion Matrix – XGBoost")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()
